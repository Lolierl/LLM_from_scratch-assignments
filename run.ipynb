# %%
s = "“我能吞下玻璃而不伤身体。I can eat glass, it does not hurt me.”"
print(s.encode("utf-8"))
utf8_bytes = list(s.encode("utf-8"))
print(utf8_bytes)
print(len(utf8_bytes))
# Out:
# b'\xe2\x80\x9c\xe6\x88\x91\xe8\x83\xbd\xe5\x90\x9e\xe4\xb8\x8b\xe7\x8e\xbb\xe7\x92\x83\xe8\x80\x8c\xe4\xb8\x8d\xe4\xbc\xa4\xe8\xba\xab\xe4\xbd\x93\xe3\x80\x82I can eat glass, it does not hurt me.\xe2\x80\x9d'
# [226, 128, 156, 230, 136, 145, 232, 131, 189, 229, 144, 158, 228, 184, 139, 231, 142, 187, 231, 146, 131, 232, 128, 140, 228, 184, 141, 228, 188, 164, 232, 186, 171, 228, 189, 147, 227, 128, 130, 73, 32, 99, 97, 110, 32, 101, 97, 116, 32, 103, 108, 97, 115, 115, 44, 32, 105, 116, 32, 100, 111, 101, 115, 32, 110, 111, 116, 32, 104, 117, 114, 116, 32, 109, 101, 46, 226, 128, 157]
# 79

# %%
s = 'Do you like this course? No. Feel boring?' + chr(8)*17 + ' YES!!!!!!!!!!!!!'
print(s)
# Out:
# Do you like this course? No. Feel boring YES!!!!!!!!!!!!!
